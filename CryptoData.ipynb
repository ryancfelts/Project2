# %%
import requests
import shrimpy
import json
import pandas as pd
from functools import reduce

# %%
# API keys for shrimpy and create client

public_key = '9feb6543757418820ebe62b5bb2ca5e3aaef013ea172ca13c31a1147408a559c'
secret_key = 'b2c814e47326a6b969848b49248d6248245a0e5bc86beab6a65ccfa6ffbfffda1637ede2d89298153d207f0028f472cafb8ad1bae37358acc54da2832c1fbff0'
client = shrimpy.ShrimpyApiClient(public_key, secret_key)

# %%
# Pulling data from each cryptocurrency

btc_data = client.get_historical_candles(
    'Bittrex',
    'BTC',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

eth_data = client.get_historical_candles(
    'Bittrex',
    'ETH',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)



ada_data = client.get_historical_candles(
    'Bittrex',
    'ADA',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)


xrp_data = client.get_historical_candles(
    'Bittrex',
    'XRP',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)


ltc_data = client.get_historical_candles(
    'Bittrex',
    'LTC',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

trx_data = client.get_historical_candles(
    'Bittrex',
    'TRX',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

usdt_data = client.get_historical_candles(
    'Bittrex',
    'USDT',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

dgb_data = client.get_historical_candles(
    'Bittrex',
    'DGB',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

tusd_data = client.get_historical_candles(
    'Bittrex',
    'TUSD',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

bsv_data = client.get_historical_candles(
    'Bittrex',
    'BSV',
    'USD',
    '2019-03-20T00:00:00.000Z',
    '2021-03-20T00:00:00.000Z',
    1000,
    '1d'
)

# %%
# Putting data into dataframes

btc_df = pd.DataFrame(btc_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
btc_df.set_index(pd.to_datetime(btc_df['time'], infer_datetime_format=True), inplace=True)
btc_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
btc_df.columns = ["BTC open", "BTC high", "BTC low", "BTC close", "BTC volume"]




eth_df = pd.DataFrame(eth_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
eth_df.set_index(pd.to_datetime(eth_df['time'], infer_datetime_format=True), inplace=True)
eth_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
eth_df.columns = ["ETH open", "ETH high", "ETH low", "ETH close", "ETH volume"]




ada_df = pd.DataFrame(ada_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
ada_df.set_index(pd.to_datetime(ada_df['time'], infer_datetime_format=True), inplace=True)
ada_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
ada_df.columns = ["ADA open", "ADA high", "ADA low", "ADA close", "ADA volume"]




usdt_df = pd.DataFrame(usdt_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
usdt_df.set_index(pd.to_datetime(usdt_df['time'], infer_datetime_format=True), inplace=True)
usdt_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
usdt_df.columns = ["USDT open", "USDT high", "USDT low", "USDT close", "USDT volume"]




xrp_df = pd.DataFrame(xrp_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
xrp_df.set_index(pd.to_datetime(xrp_df['time'], infer_datetime_format=True), inplace=True)
xrp_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
xrp_df.columns = ["XRP open", "XRP high", "XRP low", "XRP close", "XRP volume"]




ltc_df = pd.DataFrame(ltc_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
ltc_df.set_index(pd.to_datetime(ltc_df['time'], infer_datetime_format=True), inplace=True)
ltc_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
ltc_df.columns = ["LTC open", "LTC high", "LTC low", "LTC close", "LTC volume"]




trx_df = pd.DataFrame(trx_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
trx_df.set_index(pd.to_datetime(trx_df['time'], infer_datetime_format=True), inplace=True)
trx_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
trx_df.columns = ["TRX open", "TRX high", "TRX low", "TRX close", "TRX volume"]




tusd_df = pd.DataFrame(tusd_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
tusd_df.set_index(pd.to_datetime(tusd_df['time'], infer_datetime_format=True), inplace=True)
tusd_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
tusd_df.columns = ["TUSD open", "TUSD high", "TUSD low", "TUSD close", "TUSD volume"]




dgb_df = pd.DataFrame(dgb_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
dgb_df.set_index(pd.to_datetime(dgb_df['time'], infer_datetime_format=True), inplace=True)
dgb_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
dgb_df.columns = ["DGB open", "DGB high", "DGB low", "DGB close", "DGB volume"]




bsv_df = pd.DataFrame(bsv_data, columns=['open', 'high', 'low', 'close', 'volume', 'quoteVolume', 'time'])
bsv_df.set_index(pd.to_datetime(bsv_df['time'], infer_datetime_format=True), inplace=True)
bsv_df.drop(columns = ['time', 'quoteVolume'], inplace = True)
bsv_df.columns = ["BSV open", "BSV high", "BSV low", "BSV close", "BSV volume"]

# %%
# Cleaning up the dataframes

btc_df["BTC open"] = btc_df["BTC open"].astype("float")
btc_df["BTC high"] = btc_df["BTC high"].astype("float")
btc_df["BTC low"] = btc_df["BTC low"].astype("float")
btc_df["BTC close"] = btc_df["BTC close"].astype("float")
btc_df["BTC volume"] = btc_df["BTC volume"].astype("float")
btc_df['BTC daily_return'] = btc_df['BTC close'].dropna().pct_change()


eth_df["ETH open"] = eth_df["ETH open"].astype("float")
eth_df["ETH high"] = eth_df["ETH high"].astype("float")
eth_df["ETH low"] = eth_df["ETH low"].astype("float")
eth_df["ETH close"] = eth_df["ETH close"].astype("float")
eth_df["ETH volume"] = eth_df["ETH volume"].astype("float")
eth_df['ETH daily_return'] = eth_df['ETH close'].dropna().pct_change()


ada_df["ADA open"] = ada_df["ADA open"].astype("float")
ada_df["ADA high"] = ada_df["ADA high"].astype("float")
ada_df["ADA low"] = ada_df["ADA low"].astype("float")
ada_df["ADA close"] = ada_df["ADA close"].astype("float")
ada_df["ADA volume"] = ada_df["ADA volume"].astype("float")
ada_df['ADA daily_return'] = ada_df['ADA close'].dropna().pct_change()


usdt_df["USDT open"] = usdt_df["USDT open"].astype("float")
usdt_df["USDThigh"] = usdt_df["USDT high"].astype("float")
usdt_df["USDT low"] = usdt_df["USDT low"].astype("float")
usdt_df["USDT close"] = usdt_df["USDT close"].astype("float")
usdt_df["USDT volume"] = usdt_df["USDT volume"].astype("float")
usdt_df['USDT daily_return'] = usdt_df['USDT close'].dropna().pct_change()


xrp_df["XRP open"] = xrp_df["XRP open"].astype("float")
xrp_df["XRP high"] = xrp_df["XRP high"].astype("float")
xrp_df["XRP low"] = xrp_df["XRP low"].astype("float")
xrp_df["XRP close"] = xrp_df["XRP close"].astype("float")
xrp_df["XRP volume"] = xrp_df["XRP volume"].astype("float")
xrp_df['XRP daily_return'] = xrp_df['XRP close'].dropna().pct_change()


ltc_df["LTC open"] = ltc_df["LTC open"].astype("float")
ltc_df["LTC high"] = ltc_df["LTC high"].astype("float")
ltc_df["LTC low"] = ltc_df["LTC low"].astype("float")
ltc_df["LTC close"] = ltc_df["LTC close"].astype("float")
ltc_df["LTC volume"] = ltc_df["LTC volume"].astype("float")
ltc_df['LTC daily_return'] = ltc_df['LTC close'].dropna().pct_change()


trx_df["TRX open"] = trx_df["TRX open"].astype("float")
trx_df["TRX high"] = trx_df["TRX high"].astype("float")
trx_df["TRX low"] = trx_df["TRX low"].astype("float")
trx_df["TRX close"] = trx_df["TRX close"].astype("float")
trx_df["TRX volume"] = trx_df["TRX volume"].astype("float")
trx_df['TRX daily_return'] = trx_df['TRX close'].dropna().pct_change()


tusd_df["TUSD open"] = tusd_df["TUSD open"].astype("float")
tusd_df["TUSD high"] = tusd_df["TUSD high"].astype("float")
tusd_df["TUSD low"] = tusd_df["TUSD low"].astype("float")
tusd_df["TUSD close"] = tusd_df["TUSD close"].astype("float")
tusd_df["TUSD volume"] = tusd_df["TUSD volume"].astype("float")
tusd_df['TUSD daily_return'] = tusd_df['TUSD close'].dropna().pct_change()


dgb_df["DGB open"] = dgb_df["DGB open"].astype("float")
dgb_df["DGB high"] = dgb_df["DGB high"].astype("float")
dgb_df["DGB low"] = dgb_df["DGB low"].astype("float")
dgb_df["DGB close"] = dgb_df["DGB close"].astype("float")
dgb_df["DGB volume"] = dgb_df["DGB volume"].astype("float")
dgb_df['DGB daily_return'] = dgb_df['DGB close'].dropna().pct_change()


bsv_df["BSV open"] = bsv_df["BSV open"].astype("float")
bsv_df["BSV high"] = bsv_df["BSV high"].astype("float")
bsv_df["BSV low"] = bsv_df["BSV low"].astype("float")
bsv_df["BSV close"] = bsv_df["BSV close"].astype("float")
bsv_df["BSV volume"] = bsv_df["BSV volume"].astype("float")
bsv_df['BSV daily_return'] = bsv_df['BSV close'].dropna().pct_change()

# %%
dfs = [btc_df, eth_df, ada_df, usdt_df, xrp_df, ltc_df, trx_df, tusd_df, dgb_df, bsv_df]

# %%
crypto_df = reduce(lambda left,right: pd.merge(left,right,on='time'), dfs)
crypto_df.head()
# Out:
#                            BTC open  BTC high   BTC low  BTC close  \
# time
# 2019-03-20 00:00:00+00:00  4001.567  4045.441  3965.001   4036.183
# 2019-03-21 00:00:00+00:00  4035.178  4055.000  3910.000   3975.867
# 2019-03-22 00:00:00+00:00  3975.864  3998.000  3962.051   3982.000
# 2019-03-23 00:00:00+00:00  3982.000  3999.666  3960.011   3985.089
# 2019-03-24 00:00:00+00:00  3985.089  3985.089  3947.071   3968.389
#
#                            BTC volume  BTC daily_return  ETH open  ETH high  \
# time
# 2019-03-20 00:00:00+00:00  912.181350               NaN   138.000   139.275
# 2019-03-21 00:00:00+00:00  960.528554         -0.014944   138.644   139.064
# 2019-03-22 00:00:00+00:00  504.662766          0.001543   134.520   136.857
# 2019-03-23 00:00:00+00:00  426.316257          0.000776   135.761   137.515
# 2019-03-24 00:00:00+00:00  319.996194         -0.004191   136.184   136.484
#
#                            ETH low  ETH close  ...  DGB low  DGB close  \
# ...

# %%
df_closing_prices = pd.DataFrame()

df_closing_prices["BTC Close"] = btc_df["BTC close"]
df_closing_prices["ETH Close"] = eth_df["ETH close"]
df_closing_prices["ADA Close"] = ada_df["ADA close"]
df_closing_prices["USDT Close"] = usdt_df["USDT close"]
df_closing_prices["XRP Close"] = xrp_df["XRP close"]
df_closing_prices["LTC Close"] = ltc_df["LTC close"]
df_closing_prices["TRX Close"] = trx_df["TRX close"]
df_closing_prices["TUSD Close"] = tusd_df["TUSD close"]
df_closing_prices["DGB Close"] = dgb_df["DGB close"]
df_closing_prices["BSV Close"] = bsv_df["BSV close"]

df_closing_prices.head()
# Out:
#                            BTC Close  ETH Close  ADA Close  USDT Close  \
# time
# 2019-03-20 00:00:00+00:00   4036.183    138.856      0.054       0.996
# 2019-03-21 00:00:00+00:00   3975.867    134.669      0.054       0.997
# 2019-03-22 00:00:00+00:00   3982.000    135.941      0.057       0.996
# 2019-03-23 00:00:00+00:00   3985.089    136.260      0.064       0.995
# 2019-03-24 00:00:00+00:00   3968.389    135.538      0.062       0.998
#
#                            XRP Close  LTC Close  TRX Close  TUSD Close  \
# time
# 2019-03-20 00:00:00+00:00      0.317     60.136      0.023       0.999
# 2019-03-21 00:00:00+00:00      0.309     58.522      0.022       0.999
# 2019-03-22 00:00:00+00:00      0.310     59.241      0.023       1.002
# 2019-03-23 00:00:00+00:00      0.310     60.680      0.024       1.001
# 2019-03-24 00:00:00+00:00      0.306     59.527      0.023       1.001
#
#                            DGB Close  BSV Close
# time
# ...

# %%
crypto_data_csv = crypto_df.to_csv('CryptoData.csv', index = True)
btc_data_csv = btc_df.to_csv('BitcoinData.csv', index = True)
eth_data_csv = eth_df.to_csv('EthereumData.csv', index = True)
ada_data_csv = ada_df.to_csv('CardanoData.csv', index = True)
usdt_data_csv = usdt_df.to_csv('TetherData.csv', index = True)
xrp_data_csv = xrp_df.to_csv('RippleData.csv', index = True)
ltc_data_csv = ltc_df.to_csv('LitecoinData.csv', index = True)
trx_data_csv = trx_df.to_csv('TronData.csv', index = True)
tusd_data_csv = tusd_df.to_csv('TrueUSDData.csv', index = True)
dgb_data_csv = dgb_df.to_csv('DigiByteData.csv', index = True)
bsv_data_csv = bsv_df.to_csv('BitcoinSVData.csv', index = True)
crypto_closing_prices_csv = df_closing_prices.to_csv('CryptoClosingPrices.csv', index = True)
